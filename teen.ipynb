# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('C:/Users/YEO JIMIN/Downloads/data-master (1)/data-master/preprocessing_train1.csv',index_col=0)
test = pd.read_csv('C:/Users/YEO JIMIN/Downloads/data-master (1)/data-master/test_x_score.csv',index_col=0)

# %%
pd.set_option('display.max_columns', 100)
train.head(20)
# Out:
#     QaA   QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA   QeE  QfA   QfE  QgA  \
# 0   3.0   363  4.0  1370  5.0   997  1.0  1024  2.0  1577  5.0   539  2.0
# 1   5.0   647  5.0  1313  3.0  3387  5.0  2969  1.0  4320  3.0  2190  1.0
# 2   4.0  1623  1.0  1480  1.0  1021  4.0  3374  5.0  1333  1.0   531  4.0
# 3   3.0   504  3.0  2311  4.0   992  3.0  3245  1.0   357  2.0  1519  4.0
# 4   1.0   927  1.0   707  5.0   556  2.0  1062  1.0  1014  2.0   628  1.0
# 5   2.0   834  1.0  1769  4.0  2105  1.0  1070  5.0  1930  2.0  1258  5.0
# 6   1.0  1382  1.0  1473  5.0  1479  4.0  2403  1.0   616  2.0   549  5.0
# 7   1.0   384  1.0   908  5.0   870  1.0  1059  1.0  1266  1.0   483  1.0
# 8   5.0   795  2.0  3469  4.0  1693  3.0  1991  4.0  5922  2.0  1322  5.0
# 9   2.0  1668  1.0   866  1.0   895  1.0  1308  2.0  1715  5.0   563  5.0
# 10  1.0  1465  1.0  7581  4.0  1345  1.0   350  3.0  1747  1.0  1096  2.0
# 11  3.0  1086  2.0  3020  5.0  1997  1.0  1358  1.0  1318  2.0  1855  2.0
# ...

# %%
teen=train[train['age_group']=='10s']
teen
# Out:
#        QaA   QaE  QbA    QbE  QcA   QcE  QdA   QdE  QeA   QeE  QfA   QfE  QgA  \
# 11     3.0  1086  2.0   3020  5.0  1997  1.0  1358  1.0  1318  2.0  1855  2.0
# 12     2.0   466  4.0   1650  4.0   655  3.0  1241  5.0  1339  2.0   515  2.0
# 17     2.0   247  4.0   1097  3.0  2135  1.0   451  4.0  1756  2.0   409  1.0
# 22     4.0   366  2.0   1123  2.0  1007  2.0   581  2.0  1359  4.0  1450  2.0
# 27     1.0   368  4.0   2668  4.0   767  1.0   659  1.0   441  1.0   817  4.0
# ...    ...   ...  ...    ...  ...   ...  ...   ...  ...   ...  ...   ...  ...
# 45480  2.0   941  1.0  12535  1.0  1261  2.0  2278  5.0  5524  2.0  1540  5.0
# 45485  2.0   254  4.0    839  2.0   557  2.0   768  1.0   876  5.0   106  4.0
# 45487  4.0   454  5.0   1007  4.0   758  2.0  1117  3.0   946  1.0   364  2.0
# 45488  2.0  1050  5.0    619  4.0   328  1.0   285  1.0   602  1.0   267  1.0
# 45490  4.0   593  1.0    857  1.0  1047  4.0  1515  5.0  1690  4.0  1253  5.0
#
# ...

# %%
def show_height(ax):
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2., height + 0.1,height ,ha="center",fontsize=10)

# %%
def all_hue_count(data,feature,hue,row=1,col=2,figsize=(12,8)):
    fig,(ax1,ax2) = plt.subplots(row,col,figsize=figsize)
    sns.countplot(data=data,x = feature,ax=ax1)
    sns.countplot(data=data,x=feature,hue=hue,ax=ax2)
    show_height(ax1)
    show_height(ax2)
    ax1.set(title='all_count')
    ax2.set(title='hue_count')
    plt.tight_layout()

# %% [markdown]
# ### 사용방법
# - data : 데이터 프레임
# - feature : 내가 countplot 그릴 변수명 -> str타입으로 적어야됨
# - hue: 구분할 변수 (걍 종속변수 넣어) -> str 타입으로 적어야됨
# - row : 행
# - col: 열
#     - default 값이 1행 2열 이니까 바꾸고 싶으면 넣고 아니면 넣지말고
# - figsize: 플랏 사이즈 크기 -> (가로,세로) <--- 무조건 괄호로 넣어야되고 그거 헷갈리면 걍 figsize=(8,5) 이런식으로 ㄱ

# %%
col = ['education', 'engnat', 'gender', 'hand','married', 'race', 'religion','urban']
for i in col:
    all_hue_count(teen,i,'voted',figsize=(12,5))

# %%
sns.countplot(data=teen,x='wr_score',hue='voted')

# %%
sns.countplot(data=teen,x='wf_score',hue='voted')

# %%
sns.countplot(data=teen,x='score',hue='voted')

# %%
teen['01-06'] = teen['tp01'] - teen['tp06']
teen['02-07'] = teen['tp01'] - teen['tp07']
teen['03-08'] = teen['tp01'] - teen['tp08']
teen['04-09'] = teen['tp04'] - teen['tp09']
teen['05-10'] = teen['tp05'] - teen['tp10']

# %%
diff = ['01-06','02-07','03-08','04-09','05-10']
for i in diff:
    all_hue_count(teen,i,'voted',figsize=(20,8))
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
